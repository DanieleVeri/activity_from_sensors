# %%
import pandas as pd

# %%
df = pd.read_csv('../data/Phones_accelerometer.csv', na_filter = None)
df.head(100)
# Out:
#     Index   Arrival_Time        Creation_Time         x         y         z  \
# 0       0  1424696633908  1424696631913248572 -5.958191  0.688065  8.135345
# 1       1  1424696633909  1424696631918283972 -5.952240  0.670212  8.136536
# 2       2  1424696633918  1424696631923288855 -5.995087  0.653549  8.204376
# 3       3  1424696633919  1424696631928385290 -5.942718  0.676163  8.128204
# 4       4  1424696633929  1424696631933420691 -5.991516  0.641647  8.135345
# ..    ...            ...                  ...       ...       ...       ...
# 95     95  1424696634383  1424696632391642126 -5.764191  0.617844  8.171051
# 96     96  1424696634388  1424696632396677527 -5.771332  0.642837  8.196045
# 97     97  1424696634393  1424696632401712927 -5.821320  0.654739  8.174622
# 98     98  1424696634397  1424696632406748328 -5.782044  0.630936  8.140106
# 99     99  1424696634402  1424696632411783728 -5.832031  0.635696  8.192474
#
#    User   Model    Device     gt
# ...

# %%
df['gt'].value_counts()
# Out:
# walk          2192401
# sit           1991919
# stand         1851492
# bike          1845557
# null          1783200
# stairsup      1782010
# stairsdown    1615896
# Name: gt, dtype: int64

# %%
df2 = pd.read_csv('../data/Phones_gyroscope.csv', na_filter = None, Index =)
df2.head()
# Out:
#    Index   Arrival_Time        Creation_Time         x         y         z  \
# 0      0  1424696633909  1424696631914042029  0.013748 -0.000626 -0.023376
# 1      1  1424696633909  1424696631919046912  0.014816 -0.001694 -0.022308
# 2      2  1424696633918  1424696631924051794  0.015884 -0.001694 -0.021240
# 3      3  1424696633919  1424696631929117712  0.016953 -0.003830 -0.020172
# 4      4  1424696633928  1424696631934214148  0.015884 -0.007034 -0.020172
#
#   User   Model    Device     gt
# 0    a  nexus4  nexus4_1  stand
# 1    a  nexus4  nexus4_1  stand
# 2    a  nexus4  nexus4_1  stand
# 3    a  nexus4  nexus4_1  stand
# 4    a  nexus4  nexus4_1  stand

# %%
df2['gt'].value_counts()
# Out:
# walk          2350429
# sit           2218501
# stand         2024206
# bike          1911730
# stairsup      1884306
# null          1869627
# stairsdown    1673833
# Name: gt, dtype: int64

# %%
df3 = pd.read_csv('../data/accgyr_26.csv', na_filter = None)
df3.head()
# Out:
#    Index   Arrival_Time        Creation_Time         x         y         z  \
# 0      0  1424693577373  1424695423410546389 -2.833786 -0.893250  9.407455
# 1      2  1424693577374  1424695423420617190 -2.846878 -0.888489  9.431259
# 2      1  1424693577374  1424695423415581790 -2.859970 -0.862305  9.362228
# 3      3  1424693577375  1424695423425652591 -2.944473 -0.923004  9.402695
# 4      4  1424693577394  1424695423430687991 -3.002792 -0.925384  9.282486
#
#   User   Model    Device     gt Type
# 0    c  nexus4  nexus4_2  stand  ACC
# 1    c  nexus4  nexus4_2  stand  ACC
# 2    c  nexus4  nexus4_2  stand  ACC
# 3    c  nexus4  nexus4_2  stand  ACC
# 4    c  nexus4  nexus4_2  stand  ACC

# %%
df3 = df3[df3['gt'] != 'stand']

# %%
df3 = df3[df3['gt'] != 'sit']

# %%
df3 = df3[df3['gt'] != 'null']

# %%
df3['gt'].value_counts()
# Out:
# walk          1065982
# bike           964392
# stairsup       876335
# stairsdown     777612
# Name: gt, dtype: int64

# %%
df3.to_csv('../data/accgyr_nositstand.csv',index = False)

# %%
df4 = pd.read_csv('../data/accgyr_nositstand.csv',na_filter = None)
df4.head()
# Out:
#     Index   Arrival_Time        Creation_Time         x         y         z  \
# 0  100816  1424694246356  1424694244365606200 -0.404327 -0.919342  0.262985
# 1  100814  1424694246356  1424694244364843260 -8.636108 -1.883926  7.844940
# 2  100817  1424694246363  1424694244370641600 -0.433167 -0.979156  0.298233
# 3  100815  1424694246364  1424694244369878661 -8.538513 -1.379288  7.132019
# 4  100818  1424694246380  1424694244375677000 -0.479095 -0.984497  0.363388
#
#   User   Model    Device    gt Type
# 0    c  nexus4  nexus4_1  walk  GYR
# 1    c  nexus4  nexus4_1  walk  ACC
# 2    c  nexus4  nexus4_1  walk  GYR
# 3    c  nexus4  nexus4_1  walk  ACC
# 4    c  nexus4  nexus4_1  walk  GYR

# %%
df_zip = pd.read_csv("../data/accgyr_nositstand.csv")

# %%
df_zip['gt'].value_counts()
# Out:
# walk          1065982
# bike           964392
# stairsup       876335
# stairsdown     777612
# Name: gt, dtype: int64

# %%
df_zip = df_zip[df_zip['gt'] != 'walk']

# %%
df_zip['gt'].value_counts()
# Out:
# bike          964392
# stairsup      876335
# stairsdown    777612
# Name: gt, dtype: int64

# %%
df_zip.head()
# Out:
#         Index   Arrival_Time        Creation_Time         x         y  \
# 73011  164667  1424694598648  1424694596639680331 -3.784912 -0.045090
# 73012  164668  1424694598648  1424694596644715731 -3.907501  0.047745
# 73013  164669  1424694598651  1424694596649720614 -4.030090 -0.015335
# 73014  164670  1424694598656  1424694596654786532 -4.147919 -0.080795
# 73015  164671  1424694598664  1424694596659821932 -4.283600 -0.168869
#
#               z User   Model    Device          gt Type
# 73011  7.157013    c  nexus4  nexus4_1  stairsdown  ACC
# 73012  7.251038    c  nexus4  nexus4_1  stairsdown  ACC
# 73013  7.341492    c  nexus4  nexus4_1  stairsdown  ACC
# 73014  7.335541    c  nexus4  nexus4_1  stairsdown  ACC
# 73015  7.435516    c  nexus4  nexus4_1  stairsdown  ACC

# %%
df_zip = df_zip.sort_values(by="Arrival_Time")

# %%
df_zip.to_csv('../data/accgyr_bike_stairs2.csv',index = False)

# %%
df = pd.read_csv("../data/accgyr_stream.csv",names = 'abcdefghijkl')
df.head()
# Out:
#    a              b                    c         d         e         f  g  \
# 0  0  1424696633908  1424696631913248572 -5.958191  0.688065  8.135345  a
# 1  0  1424696633909  1424696631914042029  0.013748 -0.000626 -0.023376  a
# 2  1  1424696633909  1424696631919046912  0.014816 -0.001694 -0.022308  a
# 3  1  1424696633909  1424696631918283972 -5.952240  0.670212  8.136536  a
# 4  2  1424696633918  1424696631924051794  0.015884 -0.001694 -0.021240  a
#
#         h         i      j    k   l
# 0  nexus4  nexus4_1  stand  ACC NaN
# 1  nexus4  nexus4_1  stand  GYR NaN
# 2  nexus4  nexus4_1  stand  GYR NaN
# 3  nexus4  nexus4_1  stand  ACC NaN
# 4  nexus4  nexus4_1  stand  GYR NaN

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df.b)
